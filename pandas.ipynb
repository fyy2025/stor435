# %%
# !pip3 install pandas
# Out:
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
data={
    "Brand":["logitech","logitech","apple"],
    "Model": ["MX keys","G915 TKL","Magic Keyboard"],
    "TKL": [False,True,False]
}
df=pd.DataFrame(data)
df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## importing data

# %%
movie_df=pd.read_csv("new_movie.csv")
movie_df.head()
movie_df["Title"]
# select as a data frame
type(movie_df[["Title","Distributor"]])
# select row using loc
movie_df.iloc[0]
# filtering
movie_df.loc[movie_df["Distributor"]=="Walt Disney Studios Motion Pictures"]
# Out:
#      ...1                                              Title  \
# 0       0  Star Wars: Episode VII - The Force Awakens (2015)
# 1       1                           Avengers: Endgame (2019)
# 3       3                               Black Panther (2018)
# 4       4                      Avengers: Infinity War (2018)
# 8       8                                The Avengers (2012)
# ..    ...                                                ...
# 891   891                          Mr. Holland's Opus (1995)
# 896   896                        Bridge to Terabithia (2007)
# 902   902                                 Eight Below (2006)
# 909   909                                   Snow Dogs (2002)
# 911   911                     While You Were Sleeping (1995)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# 1    After the devastating events of Avengers: Infi...
# 3    T'Challa, heir to the hidden but advanced king...
# ...

# %%
# Sort data frame
movie_df.sort_values("domestic_sales",ascending=False)
# Out:
#      ...1                                              Title  \
# 0       0  Star Wars: Episode VII - The Force Awakens (2015)
# 1       1                           Avengers: Endgame (2019)
# 2       2                                      Avatar (2009)
# 3       3                               Black Panther (2018)
# 4       4                      Avengers: Infinity War (2018)
# ..    ...                                                ...
# 913   913                                The Notebook (2004)
# 914   914                   Jimmy Neutron: Boy Genius (2001)
# 915   915                               Eat Pray Love (2010)
# 916   916                 The Texas Chainsaw Massacre (2003)
# 917   917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# 1    After the devastating events of Avengers: Infi...
# 2    A paraplegic Marine dispatched to the moon Pan...
# ...

# %%
# append new observation
new_movie={
    "Title": "Shingekino",
    "Movie Info": "Titans",	
    "Distributor": "Japan",
    "date": "2013.4.11",	
    "year": "2013",	
    "domestic_sales": "1",
    "international_sales": "2",
    "total_sales": "3",
    "Genre": ["adventure"],	
    "Movie Runtime": "24",	
    "License": "PG13"
}
movie_df.append(new_movie,ignore_index=True)
# Out:
# /var/folders/8z/m4kbswp17qq4hy08by5m6m800000gn/T/ipykernel_64720/3112905634.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   movie_df.append(new_movie,ignore_index=True)
#       ...1                                              Title  \
# 0      0.0  Star Wars: Episode VII - The Force Awakens (2015)
# 1      1.0                           Avengers: Endgame (2019)
# 2      2.0                                      Avatar (2009)
# 3      3.0                               Black Panther (2018)
# 4      4.0                      Avengers: Infinity War (2018)
# ..     ...                                                ...
# 914  914.0                   Jimmy Neutron: Boy Genius (2001)
# 915  915.0                               Eat Pray Love (2010)
# 916  916.0                 The Texas Chainsaw Massacre (2003)
# 917  917.0                                   Zookeeper (2011)
# ...

# %%
# delete row
movie_df.drop(2)
# Out:
#      ...1                                              Title  \
# 0       0  Star Wars: Episode VII - The Force Awakens (2015)
# 1       1                           Avengers: Endgame (2019)
# 3       3                               Black Panther (2018)
# 4       4                      Avengers: Infinity War (2018)
# 5       5                     Spider-Man: No Way Home (2021)
# ..    ...                                                ...
# 913   913                                The Notebook (2004)
# 914   914                   Jimmy Neutron: Boy Genius (2001)
# 915   915                               Eat Pray Love (2010)
# 916   916                 The Texas Chainsaw Massacre (2003)
# 917   917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# 1    After the devastating events of Avengers: Infi...
# 3    T'Challa, heir to the hidden but advanced king...
# ...
